# %%
print("hello world")
# Out:
# hello world

# %%
x = 5
print(x)
type(x)
# Out:
# 5
# int

# %%
y = 5.3
print(y)
type(y)
# Out:
# 5.3
# float

# %%
s = "Fadlelmula"
print(s)
type(s)
# Out:
# Fadlelmula
# str

# %%
count = 0
while count < 9:
    print("The count is:", count)
    count =count +1

print("Good bye!")
# Out:
# The count is: 0
# The count is: 1
# The count is: 2
# The count is: 3
# The count is: 4
# The count is: 5
# The count is: 6
# The count is: 7
# The count is: 8
# Good bye!

# %%
Total = A + \
B + \
C

# %%
Days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

# %%
# Thia is just a test to make notes in python. I can use the # symbol to make notes in my code. This is useful for explaining what the code does or for leaving reminders for myself or others who may read the code later.
x = 5 
y = x + 1
print(y)
# Out:
# 6

# %%
x = "this is a demo about how to use the print function in python.\n The print function is used to display output to the console. \'It can take multiple arguments, which will be printed on the same line separated by spaces.\' You can also use the sep parameter to specify a different separator between the arguments.\n Additionally, you can use the end parameter to specify what should be printed at the end of the output,\n instead of the default newline character.\'"
print(x)
# Out:
# this is a demo about how to use the print function in python.
#  The print function is used to display output to the console. 'It can take multiple arguments, which will be printed on the same line separated by spaces.' You can also use the sep parameter to specify a different separator between the arguments.
#  Additionally, you can use the end parameter to specify what should be printed at the end of the output,
#  instead of the default newline character.'
